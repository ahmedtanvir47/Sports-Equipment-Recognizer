# %% [markdown]
# # Sports Equipment Recognizer
# The goal of this project is to classify 20 different types of sports equipment popular around the world. The types are following: <br/>
#
#
# 1.  Soccer ball
# 2.  Basketball ball
# 3.  Tennis Racket
# 4.  Baseball Bat
# 5.  Cricket Bat
# 6.  Hockey Stick
# 7.  Volleyball ball
# 8.  Badminton Shuttlecock
# 9.  Table Tennis Paddle
# 10.  Rugby Ball
# 11. Golf ball
# 12. Bowling Ball
# 13. Skateboard
# 14. Ski Poles
# 15. Ice Skates
# 16. Frisbee disc
# 17. Carrom board
# 18. Archery Bow
# 19. Boxing Gloves
# 20. Chessboard

# %% [markdown]
# # Setting Up for Inference

# %%
# !pip install -Uqq fastai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 234.5/234.5 kB 4.5 MB/s eta 0:00:00

# %%
from fastai.vision.all import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Sports Equipment
# Out:
# /content/drive/My Drive/Sports Equipment

# %%
version = 3
img_path = 'test_images'
model_path = f'models/sport-recognizer-v{version}.pkl'

# %%
model = load_learner(model_path)

# %% [markdown]
# # Inference 1
#
# **Target:** Volleyball

# %%
img = Image.open(f'{img_path}/unknown_00.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x103>

# %%
model.predict(f'{img_path}/unknown_00.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Volleyball ball',
#  tensor(19),
#  tensor([2.6624e-08, 1.6903e-07, 1.3874e-08, 4.7547e-06, 1.1631e-06, 3.0138e-06,
#          3.1005e-08, 5.7203e-08, 6.2178e-07, 9.0114e-07, 2.5046e-09, 3.6523e-07,
#          6.0072e-08, 1.0190e-06, 2.0947e-09, 2.0551e-08, 6.8266e-07, 7.1056e-06,
#          1.7515e-06, 9.9998e-01]))

# %% [markdown]
# # Inference 2
#
# **Target:** Rugby ball

# %%
img = Image.open(f'{img_path}/unknown_01.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/unknown_01.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Rugby Ball',
#  tensor(13),
#  tensor([1.0670e-07, 3.9581e-06, 2.5272e-06, 1.8653e-07, 2.9778e-08, 2.3109e-05,
#          1.2808e-08, 1.6535e-07, 1.6238e-05, 4.5812e-06, 2.7182e-05, 7.6264e-08,
#          2.0403e-07, 9.9988e-01, 4.5673e-07, 2.0512e-08, 2.5105e-06, 2.2537e-07,
#          4.0572e-06, 3.2970e-05]))

# %% [markdown]
# # Inference 3
# **Target:** Ski poles

# %%
img = Image.open(f'{img_path}/unknown_02.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/unknown_02.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Ski Poles',
#  tensor(15),
#  tensor([7.7976e-05, 2.3170e-06, 4.4617e-05, 3.4124e-07, 1.7020e-07, 5.2638e-07,
#          1.3187e-07, 1.5438e-08, 2.5286e-06, 8.5886e-09, 1.9722e-05, 4.0314e-04,
#          2.0501e-04, 8.3014e-08, 1.2969e-05, 9.9923e-01, 1.0730e-07, 1.1769e-07,
#          1.0559e-07, 1.2997e-07]))

# %% [markdown]
# # Inference 4
# **Target:** Badmintion Shuttlecock

# %%
img = Image.open(f'{img_path}/unknown_03.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
model.predict(f'{img_path}/unknown_03.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Badminton Shuttlecock',
#  tensor(1),
#  tensor([8.6852e-07, 9.9983e-01, 1.1739e-06, 2.4117e-06, 2.3230e-06, 3.0416e-08,
#          6.5851e-08, 1.6795e-06, 6.4744e-06, 8.1112e-08, 5.7501e-05, 7.5763e-08,
#          5.5381e-06, 2.6206e-06, 1.0886e-07, 8.4083e-07, 1.3029e-05, 1.3400e-09,
#          7.8216e-05, 1.6019e-06]))
